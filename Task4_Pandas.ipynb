# %%
import pandas as pd

# Load CSV file
df = pd.read_csv("students.csv")

# Display dataset
print("Dataset:")
print(df)

# First 5 rows
print("\nFirst 5 Rows:")
print(df.head())

# Last 5 rows
print("\nLast 5 Rows:")
print(df.tail())

# Columns
print("\nColumns:")
print(df.columns)

# Dataset Information
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset:
#     Name  Age     City  Marks
# 0  Disha   19   Bhopal     90
# 1  Rahul   20   Indore     85
# 2  priya   18   Ujjain     95
# 3   Aman   21   Bhopal     88
# 4  Sneha   19  Gwalior     92
#
# First 5 Rows:
#     Name  Age     City  Marks
# 0  Disha   19   Bhopal     90
# 1  Rahul   20   Indore     85
# 2  priya   18   Ujjain     95
# 3   Aman   21   Bhopal     88
# 4  Sneha   19  Gwalior     92
#
# Last 5 Rows:
#     Name  Age     City  Marks
# 0  Disha   19   Bhopal     90
# 1  Rahul   20   Indore     85
# 2  priya   18   Ujjain     95
# 3   Aman   21   Bhopal     88
# 4  Sneha   19  Gwalior     92
#
# Columns:
# Index(['Name', 'Age', 'City', 'Marks'], dtype='str')
#
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      str
#  1   Age     5 non-null      int64
#  2   City    5 non-null      str
# ...
